# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf

# %%
olist = pd.read_csv('/Users/adelaelezaj/Desktop/brazilian-ecommerce/olist_table.csv')

# %%
olist.head(10)
# Out:
#                  customer_unique_id first_order  year  month  after_6mth  \
# 0  8d50f5eadf50201ccdcedfb9e2ac8455  2017-05-15  2017      5  2017-11-15
# 1  3e43e6105506432c953e165fb2acf44c  2017-09-18  2017      9  2018-03-18
# 2  1b6c7548a2a1f9037c1fd3ddfed95f33  2017-11-13  2017     11  2018-05-13
# 3  6469f99c1f9dfae7733b25662e7f1782  2017-09-19  2017      9  2018-03-19
# 4  ca77025e7201e3b30c44b472ff346268  2017-10-09  2017     10  2018-04-09
# 5  12f5d6e1cbf93dafd9dcc19095df0b3d  2017-01-05  2017      1  2017-07-05
# 6  47c1a3033b8b77b3ab6e109eb4d5fdf3  2017-08-07  2017      8  2018-02-07
# 7  63cfc61cee11cbe306bff5857d00bfe4  2017-05-11  2017      5  2017-11-11
# 8  dc813062e0fc23409cd255f7f53c7074  2017-07-01  2017      7  2018-01-01
# 9  de34b16117594161a6a89c50b289d35a  2017-11-03  2017     11  2018-05-03
#
#    number_of_orders  total_payment  avg_payments customer_state  avg_score
# 0                17         927.63            55             SP       4.76
# ...

# %%
olist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96135 entries, 0 to 96134
# Data columns (total 10 columns):
# customer_unique_id    96135 non-null object
# first_order           96135 non-null object
# year                  96135 non-null int64
# month                 96135 non-null int64
# after_6mth            96135 non-null object
# number_of_orders      96135 non-null int64
# total_payment         96135 non-null float64
# avg_payments          96135 non-null int64
# customer_state        96135 non-null object
# avg_score             96135 non-null float64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 7.3+ MB

# %%
olist.describe()
# Out:
#                year         month  number_of_orders  total_payment  \
# count  96135.000000  96135.000000      96135.000000   96135.000000
# mean    2017.538253      6.031466          1.034379     167.107862
# std        0.505293      3.233385          0.213143     232.745894
# min     2016.000000      1.000000          1.000000       0.000000
# 25%     2017.000000      3.000000          1.000000      63.100000
# 50%     2018.000000      6.000000          1.000000     108.000000
# 75%     2018.000000      8.000000          1.000000     183.890000
# max     2018.000000     12.000000         17.000000   13664.080000
#
#        avg_payments     avg_score
# count  96135.000000  96135.000000
# mean     158.714818      4.069623
# std      219.487419      1.353536
# min        0.000000      1.000000
# 25%       61.000000      4.000000
# 50%      104.000000      5.000000
# 75%      175.000000      5.000000
# max    13664.000000      5.000000

# %%
formula = 'total_payment ~ C(customer_state) + C(avg_score)'

fitted_model = smf.ols(formula=formula, data=olist).fit()
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          total_payment   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.018
# Method:                 Least Squares   F-statistic:                     28.25
# Date:                Thu, 05 Dec 2019   Prob (F-statistic):               0.00
# Time:                        11:44:05   Log-Likelihood:            -6.5944e+05
# No. Observations:               96135   AIC:                         1.319e+06
# Df Residuals:                   96070   BIC:                         1.320e+06
# Df Model:                          64
# Covariance Type:            nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# ...
